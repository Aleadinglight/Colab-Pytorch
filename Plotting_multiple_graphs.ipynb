# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Aleadinglight/Colab-Pytorch-example/blob/master/Plotting_multiple_graphs.ipynb)

# %%
import matplotlib.pyplot as plt

year = [1950, 1970, 1990, 2010]

pop = [2.519, 3.692, 5.623, 6.972]

plt.plot(year, pop)

# this render the plot
plt.show()

# %%
import matplotlib.pyplot as plt

year = [1950, 1970, 1990, 2010]

pop = [2.519, 3.692, 5.623, 6.972]

plt.scatter(year, pop)

# this render the plot
plt.show()
